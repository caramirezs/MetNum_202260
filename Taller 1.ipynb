# %%
import numpy as np
import pandas as pd
from importlib import reload
import lib.metodos_solucion_ecuaciones
reload(lib.metodos_solucion_ecuaciones)
from lib.metodos_solucion_ecuaciones import graficar, met_biseccion, met_regula_falsi, met_newton_raphson, met_punto_fijo
from lib.metodos_solucion_ecuaciones import met_secante

# %% [markdown]
# ## Ejercicio 01
# Construya la gráfica de la función
# $$f(x) = |x| - \cos(x) $$

# %% [markdown]
# ### 1. Soluciones

# %%
f = lambda x: abs(x) - np.cos(x)

# %%
# Grafica
graficar(f, -2, 2)

# %%
# Bisección
x_1 = met_biseccion(f, -2, 0, 1e-5, verbose=False)
x_2 = met_biseccion(f, 0, 2, 1e-5, verbose=False)
# Out:
# >>> Solución encontrada después de 18 iteraciones: x->-0.739082336425781
# >>> Solución encontrada después de 18 iteraciones: x->0.739082336425781

# %%
# Regula Falsi
x_1 = met_regula_falsi(f, -2, 0, 1e-5, verbose=False)
x_2 = met_regula_falsi(f, 0, 2, 1e-5, verbose=False)
# Out:
# >>> Solución encontrada después de 7 iteraciones: x->-0.739084404608618
# >>> Solución encontrada después de 7 iteraciones: x->0.739084404608618

# %%
# Nweton - Rhapson
f = lambda x: abs(x) - np.cos(x)
derf = lambda x: x/abs(x) + np.sin(x)
x_1 = met_newton_raphson(f, derf, -0.7, 1e-5, verbose=False)
x_2 = met_newton_raphson(f, derf, 0.7, 1e-5, verbose=False)
# Out:
# >>> Solución encontrada después de 3 iteraciones: x->-0.739085133215161
# >>> Solución encontrada después de 3 iteraciones: x->0.739085133215161

# %%
# Secante
x_1 = met_secante(f, -0.8 , -0.7, 1e-5, verbose=False)
x_2 = met_secante(f, 0.6, 0.7, 1e-5, verbose=False)
# Out:
# >>> Solución encontrada después de 3 iteraciones: x->-0.739085132689579
# >>> Solución encontrada después de 4 iteraciones: x->0.739085133215169

# %%
# Punto fijo
g = lambda x: x*np.cos(x)/abs(x)
x_1 = met_punto_fijo(g, -0.8 , 1e-5, verbose=False)
x_2 = met_punto_fijo(g, 0.6, 1e-5, verbose=False)
# Out:
# >>> Solución encontrada después de 25 iteraciones: x->-0.739081953931543
# >>> Solución encontrada después de 27 iteraciones: x->0.739088181458376

# %% [markdown]
# ### 2. Tabla

# %%
met_biseccion(f, -2, 0, 1e-5)
# Out:
# ite 1 : a_0  = -2.0000, b_0  = 0.0000, p_1  = -1.00000 | e_abs: 1.000000e+00
# ite 2 : a_1  = -1.0000, b_1  = 0.0000, p_2  = -0.50000 | e_abs: 5.000000e-01
# ite 3 : a_2  = -1.0000, b_2  = -0.5000, p_3  = -0.75000 | e_abs: 2.500000e-01
# ite 4 : a_3  = -0.7500, b_3  = -0.5000, p_4  = -0.62500 | e_abs: 1.250000e-01
# ite 5 : a_4  = -0.7500, b_4  = -0.6250, p_5  = -0.68750 | e_abs: 6.250000e-02
# ite 6 : a_5  = -0.7500, b_5  = -0.6875, p_6  = -0.71875 | e_abs: 3.125000e-02
# ite 7 : a_6  = -0.7500, b_6  = -0.7188, p_7  = -0.73438 | e_abs: 1.562500e-02
# ite 8 : a_7  = -0.7500, b_7  = -0.7344, p_8  = -0.74219 | e_abs: 7.812500e-03
# ite 9 : a_8  = -0.7422, b_8  = -0.7344, p_9  = -0.73828 | e_abs: 3.906250e-03
# ite 10: a_9  = -0.7422, b_9  = -0.7383, p_10 = -0.74023 | e_abs: 1.953125e-03
# ite 11: a_10 = -0.7402, b_10 = -0.7383, p_11 = -0.73926 | e_abs: 9.765625e-04
# ite 12: a_11 = -0.7393, b_11 = -0.7383, p_12 = -0.73877 | e_abs: 4.882812e-04
# ite 13: a_12 = -0.7393, b_12 = -0.7388, p_13 = -0.73901 | e_abs: 2.441406e-04
# ite 14: a_13 = -0.7393, b_13 = -0.7390, p_14 = -0.73914 | e_abs: 1.220703e-04
# ite 15: a_14 = -0.7391, b_14 = -0.7390, p_15 = -0.73907 | e_abs: 6.103516e-05
# ite 16: a_15 = -0.7391, b_15 = -0.7391, p_16 = -0.73911 | e_abs: 3.051758e-05
# ite 17: a_16 = -0.7391, b_16 = -0.7391, p_17 = -0.73909 | e_abs: 1.525879e-05
# ite 18: a_17 = -0.7391, b_17 = -0.7391, p_18 = -0.73908 | e_abs: 7.629395e-06
# >>> Solución encontrada después de 18 iteraciones: x->-0.739082336425781
# -0.7390823364257812

# %%
met_regula_falsi(f, -2, 0, 1e-5)
# Out:
# ite 1 : a_0  = -2.0000, b_0  = 0.0000, p_1  = -0.58545 | e_abs: 1.414545e+00
# ite 2 : a_1  = -2.0000, b_1  = -0.5855, p_2  = -0.71713 | e_abs: 1.316799e-01
# ite 3 : a_2  = -2.0000, b_2  = -0.7171, p_3  = -0.73626 | e_abs: 1.912081e-02
# ite 4 : a_3  = -2.0000, b_3  = -0.7363, p_4  = -0.73873 | e_abs: 2.470423e-03
# ite 5 : a_4  = -2.0000, b_4  = -0.7387, p_5  = -0.73904 | e_abs: 3.135639e-04
# ite 6 : a_5  = -2.0000, b_5  = -0.7390, p_6  = -0.73908 | e_abs: 3.970798e-05
# ite 7 : a_6  = -2.0000, b_6  = -0.7391, p_7  = -0.73908 | e_abs: 5.026921e-06
# >>> Solución encontrada después de 7 iteraciones: x->-0.739084404608618
# -0.739084404608618

# %%
met_newton_raphson(f, derf, -0.7, 1e-5)
# Out:
# ite 1 : p_0  = -0.7000, p_1  = -0.73944 | e_abs: 3.943650e-02
# ite 2 : p_1  = -0.7394, p_2  = -0.73909 | e_abs: 3.513374e-04
# ite 3 : p_2  = -0.7391, p_3  = -0.73909 | e_abs: 2.724995e-08
# >>> Solución encontrada después de 3 iteraciones: x->-0.739085133215161
# -0.7390851332151608

# %%
met_secante(f, -0.8 , -0.7, 1e-5)
# Out:
# ite 1 : [p_-1=-0.80000, p_0 =-0.70000] p_1 =-0.7385654 | e_abs: 3.856544e-02
# ite 2 : [p_0 =-0.70000, p_1 =-0.73857] p_2 =-0.7390897 | e_abs: 5.242719e-04
# ite 3 : [p_1 =-0.73857, p_2 =-0.73909] p_3 =-0.7390851 | e_abs: 4.579479e-06
# >>> Solución encontrada después de 3 iteraciones: x->-0.739085132689579
# -0.739085132689579

# %%
met_punto_fijo(g, -0.8 , 1e-5)
# Out:
# ite 1 : p_0 =-0.80000 p_1 =-0.6967067 | e_abs: 1.032933e-01
# ite 2 : p_1 =-0.69671 p_2 =-0.7669596 | e_abs: 7.025292e-02
# ite 3 : p_2 =-0.76696 p_3 =-0.7200239 | e_abs: 4.693578e-02
# ite 4 : p_3 =-0.72002 p_4 =-0.7517900 | e_abs: 3.176614e-02
# ite 5 : p_4 =-0.75179 p_5 =-0.7304676 | e_abs: 2.132243e-02
# ite 6 : p_5 =-0.73047 p_6 =-0.7448625 | e_abs: 1.439495e-02
# ite 7 : p_6 =-0.74486 p_7 =-0.7351811 | e_abs: 9.681411e-03
# ite 8 : p_7 =-0.73518 p_8 =-0.7417093 | e_abs: 6.528189e-03
# ite 9 : p_8 =-0.74171 p_9 =-0.7373149 | e_abs: 4.394370e-03
# ite 10: p_9 =-0.73731 p_10=-0.7402764 | e_abs: 2.961485e-03
# ite 11: p_10=-0.74028 p_11=-0.7382822 | e_abs: 1.994257e-03
# ite 12: p_11=-0.73828 p_12=-0.7396258 | e_abs: 1.343642e-03
# ite 13: p_12=-0.73963 p_13=-0.7387208 | e_abs: 9.049628e-04
# ite 14: p_13=-0.73872 p_14=-0.7393305 | e_abs: 6.096528e-04
# ite 15: p_14=-0.73933 p_15=-0.7389198 | e_abs: 4.106426e-04
# ite 16: p_15=-0.73892 p_16=-0.7391965 | e_abs: 2.766260e-04
# ite 17: p_16=-0.73920 p_17=-0.7390101 | e_abs: 1.863331e-04
# ite 18: p_17=-0.73901 p_18=-0.7391357 | e_abs: 1.255187e-04
# ite 19: p_18=-0.73914 p_19=-0.7390511 | e_abs: 8.454977e-05
# ite 20: p_19=-0.73905 p_20=-0.7391081 | e_abs: 5.695426e-05
# ite 21: p_20=-0.73911 p_21=-0.7390697 | e_abs: 3.836484e-05
# ite 22: p_21=-0.73907 p_22=-0.7390955 | e_abs: 2.584312e-05
# ite 23: p_22=-0.73910 p_23=-0.7390781 | e_abs: 1.740819e-05
# ite 24: p_23=-0.73908 p_24=-0.7390899 | e_abs: 1.172639e-05
# ite 25: p_24=-0.73909 p_25=-0.7390820 | e_abs: 7.899026e-06
# >>> Solución encontrada después de 25 iteraciones: x->-0.739081953931543
# -0.7390819539315434

# %%
table_errors = [[-1,1.00E+00,-0.58545,1.41E+00,-0.73944,3.94E-02,-0.7385654,3.86E-02,-0.6967067,1.03E-01],
[-0.5,5.00E-01,-0.71713,1.32E-01,-0.73909,3.51E-04,-0.7390897,5.24E-04,-0.7669596,7.03E-02],
[-0.75,2.50E-01,-0.73626,1.91E-02,-0.73909,2.72E-08,-0.7390851,4.58E-06,-0.7200239,4.69E-02],
[-0.625,1.25E-01,-0.73873,2.47E-03,'','','','',-0.75179,3.18E-02],
[-0.6875,6.25E-02,-0.73904,3.14E-04,'','','','',-0.7304676,2.13E-02],
[-0.71875,3.13E-02,-0.73908,3.97E-05,'','','','',-0.7448625,1.44E-02],
[-0.73438,1.56E-02,-0.73908,5.03E-06,'','','','',-0.7351811,9.68E-03],
[-0.74219,7.81E-03,'','','','','','',-0.7417093,6.53E-03],
[-0.73828,3.91E-03,'','','','','','',-0.7373149,4.39E-03],
[-0.74023,1.95E-03,'','','','','','',-0.7402764,2.96E-03],
[-0.73926,9.77E-04,'','','','','','',-0.7382822,1.99E-03],
[-0.73877,4.88E-04,'','','','','','',-0.7396258,1.34E-03],
[-0.73901,2.44E-04,'','','','','','',-0.7387208,9.05E-04],
[-0.73914,1.22E-04,'','','','','','',-0.7393305,6.10E-04],
[-0.73907,6.10E-05,'','','','','','',-0.7389198,4.11E-04],
[-0.73911,3.05E-05,'','','','','','',-0.7391965,2.77E-04],
[-0.73909,1.53E-05,'','','','','','',-0.7390101,1.86E-04],
[-0.73908,7.63E-06,'','','','','','',-0.7391357,1.26E-04],
['','','','','','','','',-0.7390511,8.45E-05],
['','','','','','','','',-0.7391081,5.70E-05],
['','','','','','','','',-0.7390697,3.84E-05],
['','','','','','','','',-0.7390955,2.58E-05],
['','','','','','','','',-0.7390781,1.74E-05],
['','','','','','','','',-0.7390899,1.17E-05],
['','','','','','','','',-0.739082,7.90E-06]]
df = pd.DataFrame(table_errors)
df
# Out:
#                0            1             2            3             4  \
# 0             -1 1.000000e+00 -5.854500e-01 1.410000e+00 -7.394400e-01
# 1  -5.000000e-01 5.000000e-01 -7.171300e-01 1.320000e-01 -7.390900e-01
# 2  -7.500000e-01 2.500000e-01 -7.362600e-01 1.910000e-02 -7.390900e-01
# 3  -6.250000e-01 1.250000e-01 -7.387300e-01 2.470000e-03
# 4  -6.875000e-01 6.250000e-02 -7.390400e-01 3.140000e-04
# 5  -7.187500e-01 3.130000e-02 -7.390800e-01 3.970000e-05
# 6  -7.343800e-01 1.560000e-02 -7.390800e-01 5.030000e-06
# 7  -7.421900e-01 7.810000e-03
# 8  -7.382800e-01 3.910000e-03
# 9  -7.402300e-01 1.950000e-03
# 10 -7.392600e-01 9.770000e-04
# 11 -7.387700e-01 4.880000e-04
# 12 -7.390100e-01 2.440000e-04
# 13 -7.391400e-01 1.220000e-04
# 14 -7.390700e-01 6.100000e-05
# 15 -7.391100e-01 3.050000e-05
# 16 -7.390900e-01 1.530000e-05
# 17 -7.390800e-01 7.630000e-06
# 18
# 19
# 20
# 21
# 22
# 23
# 24
#
#               5             6            7             8            9
# 0  3.940000e-02 -7.385654e-01 3.860000e-02 -6.967067e-01 1.030000e-01
# 1  3.510000e-04 -7.390897e-01 5.240000e-04 -7.669596e-01 7.030000e-02
# 2  2.720000e-08 -7.390851e-01 4.580000e-06 -7.200239e-01 4.690000e-02
# 3                                          -7.517900e-01 3.180000e-02
# 4                                          -7.304676e-01 2.130000e-02
# 5                                          -7.448625e-01 1.440000e-02
# 6                                          -7.351811e-01 9.680000e-03
# 7                                          -7.417093e-01 6.530000e-03
# 8                                          -7.373149e-01 4.390000e-03
# 9                                          -7.402764e-01 2.960000e-03
# 10                                         -7.382822e-01 1.990000e-03
# 11                                         -7.396258e-01 1.340000e-03
# 12                                         -7.387208e-01 9.050000e-04
# 13                                         -7.393305e-01 6.100000e-04
# 14                                         -7.389198e-01 4.110000e-04
# 15                                         -7.391965e-01 2.770000e-04
# 16                                         -7.390101e-01 1.860000e-04
# 17                                         -7.391357e-01 1.260000e-04
# 18                                         -7.390511e-01 8.450000e-05
# 19                                         -7.391081e-01 5.700000e-05
# 20                                         -7.390697e-01 3.840000e-05
# 21                                         -7.390955e-01 2.580000e-05
# 22                                         -7.390781e-01 1.740000e-05
# 23                                         -7.390899e-01 1.170000e-05
# 24                                         -7.390820e-01 7.900000e-06

# %% [markdown]
# ## Ejercicio 2
# Como se ilustra en la figura, la velocidad del agua en metros por segundo, $v$ $(m/s)$, en la descarga de un tanque cilíndrico a través de un tubo largo se puede calcular como
# $$v = \sqrt{2 g H} \tanh \left(\dfrac{\sqrt{2 g H}}{2L} t\right)$$
# donde $g=9.81 \ m/s^2$, $H=$ carga hidrostática inicial (m), $L=$ longitud del tubo (m) y $t=$ tiempo transcurrido (s). Determine la carga hidrostática necesaria para obtener una velocidad de $v = 5 \ m/s$ en $2.5 \ s$ para un tubo de $4 \ m$ de longitud. Aproxima su respuesta a tres cifras decimales.

# %%
g, L, t, v = 9.81, 4, 2.5, 5
f_2 = lambda x: np.sqrt(2*g*x)*np.tanh((t*np.sqrt(2*g*x))/(2*L)) - v
graficar(f_2, 0, 5)

# %%
met_regula_falsi(f_2, 0, 4, 1e-4)
# Out:
# ite 1 : a_0  = 0.0000, b_0  = 4.0000, p_1  = 2.27547 | e_abs: 2.275474e+00
# ite 2 : a_1  = 0.0000, b_1  = 2.2755, p_2  = 1.75589 | e_abs: 5.195805e-01
# ite 3 : a_2  = 0.0000, b_2  = 1.7559, p_3  = 1.57412 | e_abs: 1.817729e-01
# ite 4 : a_3  = 0.0000, b_3  = 1.5741, p_4  = 1.50690 | e_abs: 6.721652e-02
# ite 5 : a_4  = 0.0000, b_4  = 1.5069, p_5  = 1.48152 | e_abs: 2.538028e-02
# ite 6 : a_5  = 0.0000, b_5  = 1.4815, p_6  = 1.47186 | e_abs: 9.659767e-03
# ite 7 : a_6  = 0.0000, b_6  = 1.4719, p_7  = 1.46818 | e_abs: 3.687681e-03
# ite 8 : a_7  = 0.0000, b_7  = 1.4682, p_8  = 1.46677 | e_abs: 1.409429e-03
# ite 9 : a_8  = 0.0000, b_8  = 1.4668, p_9  = 1.46623 | e_abs: 5.389211e-04
# ite 10: a_9  = 0.0000, b_9  = 1.4662, p_10 = 1.46602 | e_abs: 2.061014e-04
# ite 11: a_10 = 0.0000, b_10 = 1.4660, p_11 = 1.46594 | e_abs: 7.882513e-05
# >>> Solución encontrada después de 11 iteraciones: x->1.465943408996626
# 1.4659434089966261

# %% [markdown]
# ## Ejercicio 3
# Considere todos los métodos vistos para aproximar $\sqrt[4]{2}$ con una precisión de $10^{-10}$ (\textit{Sugerencia}: puede plantear la ecuación como $x^4 -2 = 0$).

# %%
f_4 = lambda x: x**4 - 2
df_4 = lambda x: 4*x**3
met_newton_raphson(f_4, df_4, 1, 1e-10)
met_secante(f_4, 1.1, 1.2, 1e-10)
# Out:
# ite 1 : p_0  = 1.0000, p_1  = 1.25000 | e_abs: 2.500000e-01
# ite 2 : p_1  = 1.2500, p_2  = 1.19350 | e_abs: 5.650000e-02
# ite 3 : p_2  = 1.1935, p_3  = 1.18923 | e_abs: 4.269779e-03
# ite 4 : p_3  = 1.1892, p_4  = 1.18921 | e_abs: 2.310537e-05
# ite 5 : p_4  = 1.1892, p_5  = 1.18921 | e_abs: 6.733967e-10
# ite 6 : p_5  = 1.1892, p_6  = 1.18921 | e_abs: 0.000000e+00
# >>> Solución encontrada después de 6 iteraciones: x->1.189207115002721
# ite 1 : [p_-1=1.10000, p_0 =1.20000] p_1 =1.1879245 | e_abs: 1.207547e-02
# ite 2 : [p_0 =1.20000, p_1 =1.18792] p_2 =1.1891898 | e_abs: 1.265242e-03
# ite 3 : [p_1 =1.18792, p_2 =1.18919] p_3 =1.1892071 | e_abs: 1.737260e-05
# ite 4 : [p_2 =1.18919, p_3 =1.18921] p_4 =1.1892071 | e_abs: 2.808587e-08
# ite 5 : [p_3 =1.18921, p_4 =1.18921] p_5 =1.1892071 | e_abs: 6.143974e-13
# >>> Solución encontrada después de 5 iteraciones: x->1.189207115002721
# 1.189207115002721
